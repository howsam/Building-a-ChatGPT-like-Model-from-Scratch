# %% [markdown]
# #  <font color='#FFE15D'><b>💎 Train GPT-2 on TinyStories Dataset </b></font><font color='#FF0B55'></font>

# %% [markdown]
# # 🔴 **Environment Setup**

# %% [markdown]
# ## 🟠 Change the font size of the output cells

# %%
print('Salam Howsam!')

# %%
from IPython.display import HTML
shell = get_ipython()

def adjust_font_size():
  display(HTML('''<style>
    body {
      font-size: 20px;
    }
  '''))

if adjust_font_size not in shell.events.callbacks['pre_execute']:
  shell.events.register('pre_execute', adjust_font_size)

# %%
print('Salam Howsam!')

# %% [markdown]
# ## 🟠 `pip`

# %% [markdown]
# # 🔴 **Import**

# %%
import os
import sys
import time
import math
import json
import yaml
import random
from tqdm import tqdm
from pprint import pprint
from itertools import cycle
from datetime import datetime
from termcolor import colored
from dataclasses import dataclass, asdict
from prettytable import PrettyTable

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from datasets import load_dataset
from tokenizers import Tokenizer

import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn import functional as F

from torchmetrics import MeanMetric
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
import tokenizers
tokenizers.__version__
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# '0.19.1'

# %% [markdown]
# # 🔴 **Utils**

# %%
def prepare_data(tokens, seq_len):
    # Trim tokens so that total length is divisible by seq_len
    n_tokens = (tokens.shape[0] // seq_len) * seq_len
    tokens = tokens[:n_tokens]
    # Reshape to 2D tensor
    return tokens.view(-1, seq_len)
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
def num_trainable_params(model):
  nums = sum(p.numel() for p in model.parameters() if p.requires_grad)/1e6
  return nums
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
# Benchmarking function
def calculate_time(model, x, num_runs=10):
    torch.cuda.synchronize()
    start = time.time()
    for _ in range(num_runs):
        model(x)
    torch.cuda.synchronize()
    return (time.time() - start) / num_runs
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# # 🔴 **Dataset**

# %%
class TinyStoriesDataset(Dataset):

    def __init__(self, data, seq_len):
        self.seq_len = seq_len
        self.data = prepare_data(data, seq_len+1)

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):
        sample = self.data[idx]
        return sample.long()#[:-1], sample[1:]
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# # 🔴 **Model**

# %% [markdown]
# ## 🟠 Multi Head Attention

# %%
class MultiHeadAttention(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.n_embd = config.n_embd
        self.n_head = config.n_head
        self.head_size = self.n_embd // self.n_head

        self.qkv_proj = nn.Linear(self.n_embd, 3*self.n_embd, bias=False)
        self.c_proj = nn.Linear(self.n_embd, self.n_embd, bias=False)
        self.c_proj.residual = True

    def forward(self, x):
        B, T, C = x.shape
        # QKV linear
        q, k, v = self.qkv_proj(x).view(B, T, 3*self.n_head, self.head_size).transpose(1, 2).chunk(3, dim=-3)
        # Scaled Dot Product Attention using pytorch
        y = F.scaled_dot_product_attention(q, k, v, is_causal=True)
        # Reshape and final projection
        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.c_proj(y)
        return y
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# ## 🟠 Feed Forward (MLP)

# %%
class FeedForward(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.n_embd = config.n_embd
        self.f_expnd = config.f_expnd

        self.up_proj = nn.Linear(self.n_embd, int(self.f_expnd*self.n_embd), bias=False)
        self.down_proj = nn.Linear(int(self.f_expnd*self.n_embd), self.n_embd, bias=False)
        self.down_proj.residual = True

    def forward(self, x):
        return self.down_proj(F.gelu(self.up_proj(x)))
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# ## 🟠 Decoder Block

# %%
class DecoderBlock(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.n_embd = config.n_embd
        # Multi Head Attention
        self.ln1 = nn.LayerNorm(config.n_embd)
        self.mha = MultiHeadAttention(config)
        # Feed Forward Neural Network
        self.ln2 = nn.LayerNorm(config.n_embd)
        self.mlp = FeedForward(config)

    def forward(self, x):
        x = x + self.mha(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# ## 🟠 GPT

# %%
class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.config = config
        self.wte = nn.Embedding(config.vocab_size, config.n_embd) # Token embedding
        self.wpe = nn.Embedding(config.max_seq_len, config.n_embd) # Position embedding
        self.decoders = nn.ModuleList([DecoderBlock(config) for _ in range(config.n_layer)]) # Decoders
        self.lnf = nn.LayerNorm(config.n_embd)
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False) # Classifier
        self.lm_head.weight = self.wte.weight # Weight tying

        self.apply(self._init_weights)

    def _init_weights(self, module):
        std = 0.02
        if isinstance(module, nn.Linear):
            if hasattr(module, 'residual'):
                std *= (2*self.config.n_layer)**-0.5
            nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=std)

    def forward(self, idx):
        B, T = idx.shape
        # Token Embedding + Position Embedding
        x = self.wte(idx) + self.wpe(torch.arange(T, device=idx.device))
        # Decoders
        for decoder in self.decoders:
            x = decoder(x)
        # Classifier
        x = self.lnf(x)
        logits = self.lm_head(x)
        return logits
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# # 🔴 **Config**

# %%
@dataclass
class DatasetConfig:
    train_path: str
    valid_path: str
    tokenizer_path: str
    batch_size: int = 32
    seq_len: int = 128


@dataclass
class GPTConfig:
    vocab_size: int = 50257
    max_seq_len: int = 1024
    n_layer: int = 12
    n_head: int = 12
    n_embd: int = 768
    f_expnd: int = 4


@dataclass
class OptimizerConfig:
    max_lr: float = 3e-4
    betas: tuple = (0.9, 0.95)
    weight_decay: float = 0.1
    fused: bool = True
    warmup_steps: int = 256
    alpha: float = 0.1
    total_tokens: int = 100_000_000


@dataclass
class TrainConfig:
    seed: int = 42
    device: str = 'cuda'
    total_tokens: int = 100_000
    log_interval_tokens: int = 50_000
    log_dir: str = 'logs'
    run_name: str = 'gpt2_tinystories'


@dataclass
class GenerationConfig:
    prompts: list[str]
    T: float = 0.9
    max_seq_len: int = 128
    top_k: int = 10
    n_rep: int = 3
    seed: int = 42


@dataclass
class MasterConfig:
    data: DatasetConfig
    model: GPTConfig
    optimizer: OptimizerConfig
    train: TrainConfig
    generation: GenerationConfig
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# # 🔴 **Functions ⚙️**

# %% [markdown]
# ## 🟠 Logger

# %%
# Logger class for saving and plotting training logs
class Logger:
    """
    Manages training history logging, saving to disk, and plotting learning curves.
    """
    def __init__(self, log_dir='logs', run_name='default_run'):
        # Make dir
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        self.log_dir = os.path.join(log_dir, f"{run_name}_{timestamp}")
        os.makedirs(self.log_dir, exist_ok=False)
        # Create history dictionay
        self.history = {
            'train_loss': [],
            'valid_loss': [],
            'best_loss_valid': float('inf'),
            'seen_tokens': [],
            'elapsed_time': []
        }

    def log(self, train_loss, valid_loss, seen_tokens, elapsed_time=0):
        self.history['train_loss'].append(train_loss)
        self.history['valid_loss'].append(valid_loss)
        self.history['seen_tokens'].append(seen_tokens)
        self.history['elapsed_time'].append(elapsed_time)

    def save(self, model, optimizer):
        # Save history
        file_path = os.path.join(self.log_dir, 'loss_history.json')
        with open(file_path, 'w') as f:
            json.dump(self.history, f, indent=4)
        # Save best model and optimizer
        current_loss_valid = self.history['valid_loss'][-1]
        if current_loss_valid < self.history['best_loss_valid']:
            log = dict(model=model.state_dict(), optimizer=optimizer)
            torch.save(log, f'{self.log_dir}/best_model.pt')
            self.history['best_loss_valid'] = current_loss_valid
            print("✅ Model Saved!")
        self.plot()

    def plot(self):
        plt.figure(figsize=(10, 5))
        plt.plot(self.history['seen_tokens'], self.history['train_loss'], label='Train Loss')
        plt.plot(self.history['seen_tokens'], self.history['valid_loss'], label='Valid Loss')
        plt.xlabel('Seen Tokens')
        plt.ylabel('Loss')
        plt.title(f'Learning Curve')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(os.path.join(self.log_dir, 'learning_curve.png'))
        plt.show()
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# ## 🟠 Train ➰

# %%
# Trainer class to manage model training, evaluation and reporting
class LLMTrainer:
    """
    Trainer handles training loops, periodic evaluation, logging, and sample generation.
    """
    def __init__(self, model, optimizer, train_loader, valid_loader, tokenizer,
                 config, loss_fn=F.cross_entropy):

        self.model = model
        self.optimizer = optimizer
        self.train_loader = train_loader
        self.valid_loader = valid_loader
        self.tokenizer = tokenizer
        self.loss_fn = loss_fn
        self.config = config
        self.device = config.train.device

        self.seen_tokens = 0
        self.token_eval_counter = 0
        self.total_tokens = config.train.total_tokens
        self.log_interval_tokens = config.train.log_interval_tokens

        self.logger = Logger(log_dir=config.train.log_dir, run_name=config.train.run_name)
        self._print_config_summary()

        self.generation = config.generation

        # Save config as a yaml file
        with open(f'{self.logger.log_dir}/config.yaml', 'w') as f:
            yaml.dump(asdict(config), f, sort_keys=False, indent=4)

    def train(self):
        """
        Main training loop that stops when total token count is reached.
        """
        # Initial evaluation before any training
        initial_loss = self.evaluate()
        self.logger.log(initial_loss, initial_loss, 0)
        print(f"👶 [Initial] Train Loss (Untrained Model): {initial_loss:.4f}\n")

        loss_train = MeanMetric()
        self.model.train()
        train_iter = cycle(self.train_loader)

        step = 0
        total_steps = self.config.optimizer.total_tokens // (self.config.data.batch_size*self.config.data.seq_len) + 1
        batches = 0
        start_time = time.time()
        total_time_elapsed = 0

        with tqdm(total=self.total_tokens, desc="Training", unit="t") as pbar:
            while self.seen_tokens < self.total_tokens:
                # Get inputs
                inputs = next(train_iter).to(self.device)

                # Forward pass
                logits = self.model(inputs[:, :-1])

                # Calculate loss
                loss = self.loss_fn(logits.view(-1, logits.shape[-1]), inputs[:, 1:].flatten())

                # Backward pass
                loss.backward()

                # Clip gradients
                nn.utils.clip_grad.clip_grad_norm_(self.model.parameters(), max_norm=1.)

                # Determine and set the learning rate for this iteration
                lr = get_lr(step, total_steps, self.config.optimizer)
                for group in self.optimizer.param_groups:
                    group['lr'] = lr

                # Update model
                self.optimizer.step()
                self.optimizer.zero_grad()

                # Calc running loss
                loss_train.update(loss.item(), inputs.shape[0])

                num_tokens_this_batch = inputs[:, :-1].numel()
                self.seen_tokens += num_tokens_this_batch
                self.token_eval_counter += num_tokens_this_batch
                step += 1
                batches += 1
                elapsed = time.time() - start_time
                batches_per_sec = batches / elapsed

                pbar.set_postfix({
                    "B/S": f"{batches_per_sec:.2f}",
                    "Loss": f"{loss_train.compute().item():.4f}",
                    "LR": f"{self.optimizer.param_groups[0]['lr']:.2e}",
                })
                pbar.update(num_tokens_this_batch)

                # Evaluate & Generate & Log
                if (self.token_eval_counter >= self.log_interval_tokens) or (self.seen_tokens >= self.total_tokens):
                    total_time_elapsed += elapsed

                    # Evaluate
                    loss_valid = self.evaluate()
                    print(f"\nValid Loss: {loss_valid:.4f}")

                    # Log
                    self.logger.log(loss_train.compute().item(), loss_valid, self.seen_tokens, total_time_elapsed)
                    self.logger.save(self.model, self.optimizer)

                    # Generate
                    if self.generation:
                        self.generate()

                    # Reset
                    self.token_eval_counter = 0
                    batches = 0
                    start_time = time.time()

        self.logger.plot()

    def evaluate(self):
        """
        Evaluate model on validation set.
        """
        loss_valid = MeanMetric()
        self.model.eval()
        with torch.no_grad():
            for inputs in self.valid_loader:
                inputs = inputs.to(self.device)
                logits = self.model(inputs[:, :-1])
                loss = self.loss_fn(logits.view(-1, logits.shape[-1]), inputs[:, 1:].flatten())
                loss_valid.update(loss.item(), inputs.shape[0])
        return loss_valid.compute().item()

    def generate(self):
        """
        Generate and print text samples from the model.
        """
        generated_texts = []
        for prompt in self.generation.prompts:
            gen_text = generate(
                self.model, self.tokenizer, prompt,
                n_rep=self.generation.n_rep,
                max_seq_len=self.generation.max_seq_len,
                T=self.generation.T, top_k=self.generation.top_k,
                seed=self.generation.seed)
            generated_texts.append(gen_text)
        # TODO: Save
        # Print
        # print(150*'.')
        # item = 0
        # prompt0 = self.generation.prompts[item]
        # for gen_text in generated_texts[item]:
        #     print(colored(f"\n{prompt0}", "green"), end='')
        #     print(colored(f"{gen_text[len(prompt0):]}", "cyan"))
        #     print(150*'.')
        # print()
        item = 0
        prompt0 = self.generation.prompts[item]
        gen_text0 = generated_texts[item][0]
        print(colored(f"\n{prompt0}", "green"), end='')
        print(colored(f"{gen_text0[len(prompt0):]}", "cyan"))
        print()

    def _print_config_summary(self):
        """
        Print a summary table of training configuration.
        """
        table = PrettyTable()
        table.title = "Training Configuration Summary"
        table.field_names = ["Component", "Details"]
        # Model
        table.add_row(["Model Type", str(self.model.config).replace("Config", "")])
        # Optimizer
        optimizer_name = self.optimizer.__class__.__name__
        optimizer_params = ', '.join([f"{k}={v}" for k, v in self.optimizer.defaults.items() if k in ["lr", "betas", "weight_decay", "fused"]])
        optimizer_display = f"{optimizer_name}({optimizer_params})"
        table.add_row(["Optimizer", optimizer_display])
        # Parameters
        total_params = sum(p.numel() for p in self.model.parameters())
        te_params = self.model.wte.weight.numel()
        table.add_row(["Total Parameters (Tr+TE)", f"{total_params:,} ({total_params-te_params:,}+{te_params:,})"])

        table.add_row(["Loss Function", self.loss_fn.__name__ if hasattr(self.loss_fn, '__name__') else str(self.loss_fn)])
        table.add_row(["Batch Shape", f"{self.train_loader.batch_size}x{self.train_loader.dataset[0].shape[-1]-1}"])
        table.add_row(["Device", self.device])
        table.add_row(["Max Tokens", f"{self.total_tokens:,}"])
        table.add_row(["Log Interval Tokens", f"{self.log_interval_tokens:,}"])
        print(table)
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# ## 🟠 Optimizer

# %%
def configure_optimizer(model, config: OptimizerConfig):
    # start with all of the candidate parameters (that require grad)
    param_dict = {n: p for n, p in model.named_parameters() if p.requires_grad}

    # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
    # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
    decay_params = [p for _, p in param_dict.items() if p.ndim >= 2]
    nodecay_params = [p for _, p in param_dict.items() if p.ndim < 2]

    optim_groups = [
        {"params": decay_params, "weight_decay": config.weight_decay},
        {"params": nodecay_params, "weight_decay": 0.0}
    ]

    num_decay_params = sum(p.numel() for p in decay_params)
    num_nodecay_params = sum(p.numel() for p in nodecay_params)
    print(f"🔹 num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
    print(f"🔹 num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")

    # Define Optimizer
    optimizer = torch.optim.AdamW(
        optim_groups,
        lr=config.max_lr,
        betas=config.betas,
        fused=config.fused)

    return optimizer
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
def get_lr(step, total_steps, config: OptimizerConfig):
    # assert step <= total_steps

    # 1. Linear warmup for warmup_steps
    if step < config.warmup_steps:
        return config.max_lr * (step+1) / config.warmup_steps

    # 2. Linear decay down to min learning rate
    decay_ratio = (step - config.warmup_steps) / (total_steps - config.warmup_steps) # [0, 1]
    # assert 0 <= decay_ratio <= 1
    if decay_ratio > 1:
        decay_ratio = 1
    return config.max_lr * (config.alpha + (1 - decay_ratio)) / (config.alpha + 1)
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# ## 🟠 Generate

# %%
def generate(model, tokenizer, prompt, n_rep=5, max_seq_len=128, T=0.9, top_k=10, device='cuda', seed=42):
    # Get the token ID for <|endoftext|>
    eot_token_id = tokenizer.encode("<|endoftext|>").ids[0]

    # Tokenize the prompt and convert it to a tensor on the specified device (e.g., GPU)
    inputs = torch.tensor(tokenizer.encode(prompt).ids, dtype=torch.int, device=device)  # Shape: [T]

    # Repeat the input prompt n_rep times to generate multiple sequences in parallel
    inputs = inputs.unsqueeze(0).repeat(n_rep, 1)  # Shape: [B, T] where B = n_rep

    # Set the model to evaluation mode
    model.eval()

    # Initialize a random number generator for sampling
    sample_rng = torch.Generator(device=device)
    sample_rng.manual_seed(seed)

    # Track which sequences are still active
    is_finished = torch.zeros(n_rep, dtype=torch.bool, device=device)

    # Disable gradient calculation for faster inference
    with torch.no_grad():
        # Continue generating tokens until reaching the maximum sequence length
        while inputs.shape[-1] < max_seq_len:
            # Forward pass: get logits from the model
            logits = model(inputs)  # Shape: [B, T, vocab_size]

            # Apply temperature scaling and softmax to get probabilities for the next token
            probs = torch.softmax(logits[:, -1, :] / T, dim=-1)  # Shape: [B, vocab_size]

            # Select the top_k tokens with the highest probabilities
            topk_probs, topk_indices = torch.topk(probs, k=top_k, dim=-1)  # Shape: [B, top_k]

            # Sample one token from the top_k candidates based on their probabilities
            sampled = torch.multinomial(topk_probs, 1, generator=sample_rng)  # Shape: [B, 1]

            # Map the sampled indices back to the original token IDs
            next_token = torch.gather(topk_indices, -1, sampled).squeeze(-1) # Shape: [B]

            # For finished sequences, force pad with eot_token_id again to avoid changing inputs
            next_token = torch.where(is_finished, torch.tensor(eot_token_id, device=device), next_token)

            # Update finished mask
            is_finished = is_finished | (next_token == eot_token_id)

            # Append the sampled tokens to the input sequence
            inputs = torch.cat((inputs, next_token.unsqueeze(-1)), dim=-1)  # Shape: [B, T+1]

    # Decode the generated sequences back into text
    generated_text = tokenizer.decode_batch(inputs.tolist())

    return generated_text
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
def display_chat_style(prompt, generated_text, tokenizer, delay=0.03):
    """
    Display generated text in a token-by-token ChatGPT-like style:
    - prompt in green
    - generated continuation in blue
    """
    for i, full_text in enumerate(generated_text):
        print(colored(f"\n[Sample {i+1}]", "yellow"))
        input_ids = tokenizer.encode(prompt).ids
        full_ids = tokenizer.encode(full_text).ids

        # Split into prompt tokens and continuation
        prompt_tokens = full_ids[:len(input_ids)]
        continuation_tokens = full_ids[len(input_ids):]

        # Decode tokens separately
        prompt_text = tokenizer.decode(prompt_tokens)
        cont_tokens_text = [tokenizer.decode([tid]) for tid in continuation_tokens]

        # Print prompt in green
        sys.stdout.write(colored(prompt_text, 'green'))
        sys.stdout.flush()

        # Print continuation token-by-token in blue
        for token in cont_tokens_text:
            sys.stdout.write(colored(token, 'cyan'))
            sys.stdout.flush()
            time.sleep(delay)
        print()
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# # 🔴 **Training Process 〽️**

# %%
torch.cuda.empty_cache()
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
cfg = MasterConfig(

    data=DatasetConfig(
        train_path='data/tokenized-train-samples_vocab-10k.pt',
        valid_path='data/tokenized-valid-samples_vocab-10k.pt',
        tokenizer_path='data/bpe-tokenizer_tinystories.json',
        batch_size=48,
        seq_len=512),

    model=GPTConfig(
        vocab_size=10_000,
        max_seq_len=1024,
        n_layer=8,
        n_head=16,
        n_embd=128,
        f_expnd=4),

    optimizer=OptimizerConfig(
        max_lr=0.01,
        betas=(0.9, 0.95),
        weight_decay=0.1,
        fused=True,
        alpha=0.00001,
        total_tokens=200_000_000),

    train=TrainConfig(
        seed=42,
        device='cuda',
        total_tokens=200_000_000,
        log_interval_tokens=20_000_000,
        log_dir='logs',
        run_name='gpt2_tinystories_model2M'),

    generation=GenerationConfig(
        prompts=['In last'],
        T=0.9,
        max_seq_len=512,
        top_k=10,
        n_rep=3,
        seed=42)
    )
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
# Set a manual seed for reproducibility across runs
torch.manual_seed(cfg.train.seed)

# Load pre-tokenized training and validation token IDs from disk
train_token_ids = torch.load(cfg.data.train_path)
valid_token_ids = torch.load(cfg.data.valid_path)

print("📊 Number of Tokens")
print(f"🔹 Train: {len(train_token_ids):,} tokens")
print(f"🔹 Valid: {len(valid_token_ids):,} tokens")
print()


# Create dataset instances with fixed-length sequences
train_set = TinyStoriesDataset(train_token_ids, cfg.data.seq_len)
valid_set = TinyStoriesDataset(valid_token_ids, cfg.data.seq_len)


# Create DataLoaders for batching and shuffling during training
train_loader = DataLoader(train_set, batch_size=cfg.data.batch_size, shuffle=True, pin_memory=True)
valid_loader = DataLoader(valid_set, batch_size=cfg.data.batch_size, shuffle=False, pin_memory=True)

print(f"📊 Number of Batches")
print(f"🔹 Train: {len(train_loader):,} batches")
print(f"🔹 Valid: {len(valid_loader):,} batches")
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# 📊 Number of Tokens
# 🔹 Train: 464,965,814 tokens
# 🔹 Valid: 4,673,588 tokens
#
# 📊 Number of Batches
# 🔹 Train: 18,883 batches
# 🔹 Valid: 190 batches

# %%
tokenizer = Tokenizer.from_file(cfg.data.tokenizer_path)
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
model = GPT(cfg.model).to(cfg.train.device)

print(model)
print(f"\n📊 Number of Parameters: {num_trainable_params(model):.2f}M")
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# GPT(
#   (wte): Embedding(10000, 128)
#   (wpe): Embedding(1024, 128)
#   (decoders): ModuleList(
#     (0-7): 8 x DecoderBlock(
#       (ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mha): MultiHeadAttention(
#         (qkv_proj): Linear(in_features=128, out_features=384, bias=False)
#         (c_proj): Linear(in_features=128, out_features=128, bias=False)
#       )
#       (ln2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): FeedForward(
#         (up_proj): Linear(in_features=128, out_features=512, bias=False)
#         (down_proj): Linear(in_features=512, out_features=128, bias=False)
#       )
#     )
#   )
#   (lnf): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (lm_head): Linear(in_features=128, out_features=10000, bias=False)
# )
#
# 📊 Number of Parameters: 2.99M

# %%
optimizer = configure_optimizer(model, cfg.optimizer)
optimizer
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# 🔹 num decayed parameter tensors: 34, with 2,983,936 parameters
# 🔹 num non-decayed parameter tensors: 34, with 4,352 parameters
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.95)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: True
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.1
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.95)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: True
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.0
# )

# %%
trainer = LLMTrainer(model, optimizer, train_loader, valid_loader, tokenizer, config=cfg)
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# +-----------------------------------------------------------------------------------------------------------------+
# |                                          Training Configuration Summary                                         |
# +--------------------------+--------------------------------------------------------------------------------------+
# |        Component         |                                       Details                                        |
# +--------------------------+--------------------------------------------------------------------------------------+
# |        Model Type        | GPT(vocab_size=10000, max_seq_len=1024, n_layer=8, n_head=16, n_embd=128, f_expnd=4) |
# |        Optimizer         |           AdamW(lr=0.01, betas=(0.9, 0.95), weight_decay=0.01, fused=True)           |
# | Total Parameters (Tr+TE) |                           2,988,288 (1,708,288+1,280,000)                            |
# |      Loss Function       |                                    cross_entropy                                     |
# |       Batch Shape        |                                        48x512                                        |
# |          Device          |                                         cuda                                         |
# |        Max Tokens        |                                     200,000,000                                      |
# |   Log Interval Tokens    |                                      20,000,000                                      |
# +--------------------------+--------------------------------------------------------------------------------------+

# %%
trainer.train()
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# 👶 [Initial] Train Loss (Untrained Model): 9.2224
# Training:  10%|██                   | 20004864/200000000 [03:49<32:40, 91801.82t/s, B/S=3.77, Loss=3.3407, LR=9.29e-03]
# Valid Loss: 2.4307
# ✅ Model Saved!
# In last time, Timmy was playing in the woods. He saw a little boy crying his foot. He didn't want to get the boy. He asked the boy if he could play with him, but she knew it was too expensive.
#
# Timmy thought it was very pretty and he wanted to try to make his friend happy. He asked the boy to help him and help him. The boy thought for a moment and he was happy to help.
#
# After they finished, Timmy gave the little boy a big smile. The little boy was happy and grateful. He thanked the old man and ran away. The little boy was very happy.
# Training:  20%|████▏                | 40009728/200000000 [07:22<27:27, 97099.13t/s, B/S=3.90, Loss=2.8166, LR=8.26e-03]
# Valid Loss: 2.2153
# ✅ Model Saved!
# Training:  20%|████▏                | 40009728/200000000 [07:39<27:27, 97099.13t/s, B/S=3.90, Loss=2.8166, LR=8.26e-03]
# In last time, Ben and Lily were best friends. They liked to play together.
# Training:  30%|██████▎              | 60014592/200000000 [11:19<24:02, 97056.90t/s, B/S=3.91, Loss=2.6000, LR=7.23e-03]
# Valid Loss: 2.1359
# ✅ Model Saved!
# In last time, there was an old bird who lived in a big, old tree. The small bird would fly far away from the tree, and he was very scared.
#
# One day, the small bird found a big, dark cloud! The little bird was scared, but he knew he had to protect his friend. He flew to the light and tried to calm up to protect himself from scaring it.
#
# The moral of the story is that sometimes you know, you should take care for ourselves and be careful. Don't be scared, but it's important to always support our friends with kindness.
# Training:  40%|████████▍            | 80019456/200000000 [14:55<21:22, 93579.26t/s, B/S=3.85, Loss=2.4768, LR=6.20e-03]
# Valid Loss: 2.0837
# ✅ Model Saved!
# Training:  40%|████████▍            | 80019456/200000000 [15:09<21:22, 93579.26t/s, B/S=3.85, Loss=2.4768, LR=6.20e-03]
# In last time, it was time for Lily and her mom to go to the park. They packed their bags with her and ran to the swings. Lily saw a big tree with a lot of toys. Lily had never seen a tree so tall trees before.
#
# Suddenly, Lily saw a big dog near the slide. She wanted to go there, but the dog was hungry. Lily was sad because the dog was eating all of Lily's snacks. She didn't want to leave. The dog ran away from her, but Lily was sad. She didn't know what to do with the dog.
#
# Lily's mom saw the dog. She ran to him and said, "Don't worry, Lily. The dog has a leash, but it's not a dog. It is a dog who lives here. He lives here. He is not a dog. He is nice. He is not a dog. He is not a bad dog. He is friendly. He is his friend. He is very friendly. He can make friends. But he was scared and scared. He did not understand why he was so mean. He did not have any friends. He was not scared of his dog. He was very lonely. He did not have a friend. He was lonely. He did not want to play or explore. He was lonely and lonely.
# Training:  50%|██████████          | 100024320/200000000 [18:44<17:35, 94677.39t/s, B/S=3.83, Loss=2.3934, LR=5.16e-03]
# Valid Loss: 2.0443
# ✅ Model Saved!
# Training:  50%|██████████          | 100024320/200000000 [19:00<17:35, 94677.39t/s, B/S=3.83, Loss=2.3934, LR=5.16e-03]
# In last, there was a girl named Tim. Tim loved to play outside and explore. One day, they saw a big cliff far away. Tim thought the cliff would be fun to go in the forest.
#
# Tim and Lily were scared but they knew they could not. They looked around and saw something amazing. Tim ran up to the cliff and saw a big, mean cat. The cat hissed and started barking. Tim and Lily were scared.
#
# Then, the cat started to jump and hide. The cat ran fast and hid behind a tree. Tim and Lily were very safe. They were safe and happy. They learned that they should have stayed away from the scary forest.
# Training:  60%|████████████        | 120029184/200000000 [22:34<14:07, 94356.94t/s, B/S=3.84, Loss=2.3314, LR=4.13e-03]
# Valid Loss: 1.9993
# ✅ Model Saved!
# Training:  60%|████████████        | 120029184/200000000 [22:50<14:07, 94356.94t/s, B/S=3.84, Loss=2.3314, LR=4.13e-03]
# In last night, they were very sad. They had broken their toys. They wanted to play and have fun. But they could not find any toys.
#
# They looked around and saw a big box on the wall. It had a label in it. It said "Do not touch. Turn out my toys. There are toys and books. We can play with them and read them. Do not touch them or read or sing."
#
# Lily and Tim did not know what. They thought it was strange and scary. They did not want to hurt them. They thought it was a fun game. They decided to be brave. They decided to be brave and not touch the book. They wanted to know what it was. They opened the book and opened the box. They saw many things inside. They saw books, books, and books. They saw different things and had fun.
#
# They learned to be brave and careful around. They still liked to read and learn new things. They learned to be brave and kind. They also learned new things and learned from their toys. They hoped they would learn more about them. They learned something new. They learned that they learned to trust each other. They were proud of their toys. They learned that they had to be brave and respectful.
# Training:  70%|█████████████▎     | 140034048/200000000 [26:13<09:37, 103908.20t/s, B/S=4.02, Loss=2.2811, LR=3.10e-03]
# Valid Loss: 1.9601
# ✅ Model Saved!
# In last night, Timmy and Lily were tired and went to bed. They played together with their toys and dreamed of the big red truck.
# Training:  80%|███████████████▏   | 160038912/200000000 [29:47<06:36, 100900.52t/s, B/S=4.11, Loss=2.2375, LR=2.07e-03]
# Valid Loss: 1.9116
# ✅ Model Saved!
# Training:  80%|███████████████▏   | 160038912/200000000 [30:00<06:36, 100900.52t/s, B/S=4.11, Loss=2.2375, LR=2.07e-03]
# In last, there was a big, big, strong and strong truck. In the truck, there was a man named Tom. Tom was very angry. Tom told his friend, a little girl named Sue. Sue was not happy. They would quarrel. They would not listen to each other.
#
# Then, the big truck stopped. It had a big problem. Tom and Sue were sad. They wanted to make Tom feel bad. They wanted to help each other. So, they found a nice way to help each other. They found a way to fix the truck. Tom helped Sue and they were very happy. They learned that sharing was important.
# Training:  90%|█████████████████  | 180043776/200000000 [33:21<03:17, 101117.72t/s, B/S=4.10, Loss=2.1981, LR=1.03e-03]
# Valid Loss: 1.8580
# ✅ Model Saved!
# In last night, Jack and Jill were both very tired. They had been playing with an old dog, so it looked like nothing could be over the bed. Jill was sad, but Jack and Jill had seen an amazing surprise.
#
# In the evening, Jack and Jill went to the park. They ran around the park, laughing and having a big nap.
#
# They ran around the park, having so much fun. Then Jack and Jill spotted something special on the ground. It was a shiny star! They were so excited and they quickly ran over to it.
#
# "This is an amazing surprise!" said Jack.
#
# Jill smiled and hugged him. "Thank you so much!" she said.
#
# Then, Jack put the star on the ground. Jill smiled and said, "You're welcome!" and they both went home with a big smile on their faces.
# Training: 200024064t [36:56, 101657.96t/s, B/S=4.09, Loss=2.1608, LR=1.37e-06]
# Valid Loss: 1.8052
# ✅ Model Saved!
# Training: 200024064t [37:11, 89622.33t/s, B/S=4.09, Loss=2.1608, LR=1.37e-06]
# In last, there was a big, wide truck. The truck had a lot of boxes. One day, the truck went too fast. It went to a park and saw a big, strong truck. The truck wanted to drive the truck in the truck.
#
# The truck was very happy. It zoomed in the truck and drove around the town. The truck was very excited to see the truck. The truck went inside and made the truck go fast. The truck was happy to see the truck.
#
# But the truck did not stop. It did not stop. The truck got angry. The truck was sad. It did not know where the truck was going. The truck had a bad ending.

# %%
torch.cuda.empty_cache()
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %% [markdown]
# # 🔴 **Generate**

# %%
import textwrap

def print_colored_wrapped(prompt, generated, width=100):
    """
    Print prompt and generated text with color and line wrapping, preserving paragraph breaks (\n\n).
    """
    full_text = prompt + generated
    paragraphs = full_text.split('\n\n')  # Split by paragraph

    first = True
    for para in paragraphs:
        # Apply line wrapping per paragraph
        lines = textwrap.wrap(para, width=width)

        for line in lines:
            if first:
                # Print prompt in green and the rest in cyan
                prompt_part = line[:len(prompt)]
                gen_part = line[len(prompt):]
                print(colored(prompt_part, "green") + colored(gen_part, "cyan"))
                prompt = ''  # only on first line
                first = False
            else:
                print(colored(line, "cyan"))

        print()  # extra newline between paragraphs
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
prompts = [
    'In last night',
    'Once upon',
    'Once upon a time',
    'One day, a little boy named TimTommy was a smart 3 year old, much smarter']
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }

# %%
for prompt in prompts:
    # Generate n_rep samples
    gen_text = generate(model, tokenizer, prompt, n_rep=3, max_seq_len=512, T=0.9, top_k=10)

    # Print
    print(100*"=")
    for gtxt in gen_text:
        prompt_len = len(prompt)
        generated = gtxt[prompt_len:]
        print_colored_wrapped(prompt, generated, width=100)
        print(tokenizer.encode(gtxt))
        print(100*".")
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# ====================================================================================================
# In last night, a young boy was feeling brave. He decided to go outside and explore a new cave. The
# little boy was ready to explore and he was so excited to explore.
#
# He opened the doors and opened them. He stepped inside but he didn't know what was inside. He felt a
# sudden feeling something strange. He looked around and saw a big, black creature in the corner of
# the cave. The boy was very excited and he quickly ran inside, feeling very brave.
#
# The creature had never been so scary at all! It had come out of the cave. But it seemed like it was
# a special cave, so it had never seen before. The little boy was so excited and he decided to explore
# again. He walked around the cave and found a cozy cave. He was so happy to find out that he found
# the cave!
#
# Encoding(num_tokens=174, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# In last night, Lucy saw a beautiful flower on a table. She wanted to pick it. "Mommy, can I pick the
# lily?" asked her mommy. "Yes, you can pick the poppy," said Lucy.
#
# Her mommy picked up the flower and brought it to her. Lucy was very happy to pick up the lily
# petals. She hugged the flower and said, "I love it, mommy!"
#
# As the sun went down, Lucy started to walk away from the flower flower. She felt sad. When she
# reached the flower flower, she asked, "Mommy, can I pick the lily?"
#
# Her mommy nodded and said, "Of course, Lucy. You can keep the flower for a while. Let's go home
# now."
#
# From that day, Lucy kept her flower in her room and she always looked for the flower to pick it.
#
# Encoding(num_tokens=178, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# In last night a very cold day of three year old children came up in the kitchen. They were very
# scared and quickly started to run away.
#
# But then, the little girl felt a bit scared. She saw a small white creature in her hand, and it was
# very small. She was scared and tried to run away, but her voice was too heavy.
#
# The little girl started to get worried. She looked for a way to get away when she saw a big box of
# matches. She opened it and there was a huge, bright, shiny red light inside.
#
# Inside, there was a huge box of matches. The little girl was so excited and ran inside to show her
# family. They were all playing games and making a big house with matches.
#
# The little girl and her family had so much fun playing with the matches all day long. They laughed
# and cheered for the girl, happy and safe.
#
# Encoding(num_tokens=189, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# ====================================================================================================
# Once upon a time, there were two friends, a cat and a mouse. They wanted to find a big treasure, but
# the mouse was too scared.
#
# "Let's go find some treasure," the mouse said.
#
# "I'll be quick," the mouse said.
#
# The mouse hopped on an adventure to find the treasure. But the mouse was too shy and didn't want to
# listen.
#
# "I'm scared," the mouse said softly. "I'm brave!"
#
# The mouse smiled and whispered, "Don't be scared, little mouse. We're just trying to find a
# treasure."
#
# So the mouse and mouse walked and walked until they reached a big treasure chest. Inside the
# treasure chest, it was a treasure chest. The mouse and mouse were so happy. They played in the
# treasure all day, and the mouse thanked the mouse for being so brave and for being brave.
#
# Encoding(num_tokens=187, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# Once upon a time, there lived a very special cat. The cat loved to play games with friends and run
# around, chasing butterflies and having lots of fun.
#
# One day, the cat had to go to a new place to play. The cat was excited and wanted to find something
# new to play with.
#
# But as the cat was playing, a big dog barked at the ball. The ball was scared of the cat and wanted
# to chase it.
#
# So, the cat chased the ball for a long time, until it reached the other side. The ball was safe and
# the cat was happy.
#
# But as the cat was running, it saw a big dog. The dog was scared and ran after it. The cat ran away
# with its friend, and it was safe. The cat was happy and safe.
#
# Encoding(num_tokens=169, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# Once upon a time, there lived a little girl called Lily. One day, Lily went to the beach with her
# mommy. She saw a big, green ocean with lots of sand.
#
# Lily wanted to go for a swim, but it was raining. She said to her mommy, "I want to swim in the
# water!" But her mommy said, "No, Lily. That is too much water. You can't swim like that."
#
# Lily was sad, but her mommy said, "I'm sorry, Lily. You don't have any trouble for swimming." So
# they started swimming in the sand until it was all wet and dirty.
#
# Lily's mommy saw that Lily was so upset that they didn't have a wet towel to play in the sand.
# Lily's mommy said, "Don't worry, we can still swim with the wet towel." They swam and splashed in
# the sand until the rain stopped. Lily was happy to have her mommy to swim, and she felt happy that
# she could help her mommy.
#
# Encoding(num_tokens=210, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# ====================================================================================================
# Once upon a time, there was a big, strong, strong rabbit. The rabbit had a shiny, shiny, colorful
# bow and a pretty bow. One day, a little boy came to the forest. The rabbit wanted to be his friend.
#
# The rabbit wanted to play with the bow. The rabbit was so happy! He held the bow in his arms and
# hopped around. The rabbit was very happy with the bow. They played with the bow and the bow.
#
# The rabbit had so much fun playing with his bow. He loved to play with it, and he was the only one
# in the forest. The rabbit was very happy. And from that day on, the rabbit would always keep the bow
# in its pocket.
#
# Encoding(num_tokens=149, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# Once upon a time there was a little girl named Sally. Sally loved to play outside and explore the
# world around her. One day Sally decided to take a walk to the park. As Sally walked around, she saw
# a big, green field. She wanted to pick a bunch of grapes.
#
# Sally went up to the big tree. She saw a bunch of grapes that smelled very sour. She asked the tree
# for her grapes, but the tree was too high. Sally started to worry because she wanted some grapes,
# but there were too much.
#
# Then Sally's friend, Timmy, came over to play. He saw the grapes and was surprised. He wanted the
# grapes, but he was too busy. Sally felt sad and asked the tree what was happening. Timmy said he
# wanted the grapes, but they didn't want to share.
#
# Then, Sally saw a big, mean old man. She wanted the grapes too. Timmy was scared and asked her to
# help. He was scared and said he could help. Sally was happy to have her grapes back. She thanked the
# old man and went to her friend's house. They ate the grapes and had a good time at the park. The
# end.
#
# Encoding(num_tokens=245, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# Once upon a time there was a little bird named Tweety. Tweety lived in the garden with his friends.
# One day, Tweety's friend Billy came to visit.
#
# "Hi Billy, do you want to play with me?" asked Andy.
#
# "I want to play too," said Billy.
#
# "Me too," replied Billy. "I want to play with you!"
#
# "Okay, but be careful!" said Billy.
#
# So, they played with the ball all day long, and soon they were playing with the ball and having fun,
# but then something terrible happened. A mean man came into the garden and saw the ball.
#
# "What's wrong?" asked Billy.
#
# "I don't know how to play with the ball," said Billy.
#
# The man felt sad that he couldn't play with the ball. But he knew that he would be okay when his
# friend didn't play with him. They played together and had a great time.
#
# Encoding(num_tokens=202, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# ====================================================================================================
# One day, a little boy named TimTommy was a smart 3 year old, much smarter. He went to his mom and
# said, "Mom, I'm going to the market!" His mom said, "Okay, let's go."
#
# When they got to the market, they saw a big market. They asked if they could buy some vegetables,
# but the market said no. Tim's mom said, "We have to pay for vegetables now. But we have to go."
#
# So, Timmy got to work. He found lots of vegetables and vegetables from the market. He put the
# vegetables in the market and waited. When the market was done, his mom took him home.
#
# When they got home, the market had a big cake. There were lots of vegetables. Timmy was so happy! He
# said, "Wow! This is so delicious!" His mom smiled and said, "Yes, it is. We can take some home!"
#
# Encoding(num_tokens=195, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# One day, a little boy named TimTommy was a smart 3 year old, much smarter than what he had to do.
# One day, he was playing with his favorite toy in his backyard. When he looked over to the sky, he
# saw all the bright colors of the bright colors. He was so amazed. He wanted to know how the colors
# of the rainbow was too small to make the rainbow sparkle and beautiful. He took some of his cars and
# got them all ready for his adventure.
#
# He took some of his cars and got some of them in the garden. He played with them around in his
# garden, but then he got bored. He wanted to keep playing and play. So he decided to put all his toys
# in a box. He opened the box and found a box of toys!
#
# He was so excited, but now he had a little bit of the toys and he was so excited. He put them on and
# started to play the game. He had so much fun, and he was so proud of himself.
#
# As the sun went down, Timmy said goodbye to the big, beautiful, blue sky. He was happy that he had
# taken his toys out of the garden. He was very proud of himself for making the big, red thing to do.
#
# Encoding(num_tokens=261, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................
# One day, a little boy named TimTommy was a smart 3 year old, much smarter than the sun.
#
# He wanted to play a game of tag at school. He asked his mom for help him.
#
# "Can I play tag?" his mom asked.
#
# "Yes, you can!" said Jimmy.
#
# So, he went to the park. He took a big ball and threw his ball to the sky. He laughed and smiled.
#
# When it was time to go home, his mom gave him a big hug. He had a great day.
#
# Encoding(num_tokens=119, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# ....................................................................................................

# %%
idx = 2
tokens = []
for i, token in enumerate(ids[idx, 1:]):
    if token.item() != 1:
        tokens.append(token.item())
    else:
        break
print(len(tokens), len(ids[idx]))

pprint(tokenizer.decode(tokens))
# Out:
# <style>
#     body {
#       font-size: 20px;
#     }
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 idx = 2
#       2 tokens = []
# ----> 3 for i, token in enumerate(ids[idx, 1:]):
#       4     if token.item() != 1:
#       5         tokens.append(token.item())
#
# NameError: name 'ids' is not defined
